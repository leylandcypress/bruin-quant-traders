# %%
# %pip install yfinance --upgrade --no-cache-dir

# %%
from IPython.display import display, Latex
import pandas as pd
import numpy as np
import yfinance as yf
from scipy.optimize import minimize

# %%
# For reference:
sector_tickers = {
    'Materials': 'XLB',
    'Communication Services': 'XLC',
    'Energy': 'XLE',
    'Financials': 'XLF',
    'Industrials': 'XLI',
    'Information Technology': 'XLK',
    'Consumer Staples': 'XLP',
    'Real Estate': 'XLRE',
    'Utilities': 'XLU',
    'Health Care': 'XLV',
    'Consumer Discretionary': 'XLY'
}

# %% [markdown]
# # Gather known data:

# %% [markdown]
# As of 2/18/2025

# %% [markdown]
# **Weight vector of the 11 sector ETFs**

# %%
display(Latex('w'))
# Out:
# w

# %% [markdown]
# From the "Sector Allocation" section of SPY's website: https://www.ssga.com/us/en/individual/etfs/spdr-sp-500-etf-trust-spy

# %%
weight_series = pd.Series({'XLB': 0.0198, 'XLC': 0.0966, 'XLE': 0.0321, 'XLF': 0.1411, 'XLI': 0.0822, 'XLK': 0.3182, 'XLP': 0.0559, 'XLRE': 0.0208, 'XLU': 0.0235, 'XLV': 0.1014, 'XLY': 0.1084})
weight_series
# Out:
# XLB     0.0198
# XLC     0.0966
# XLE     0.0321
# XLF     0.1411
# XLI     0.0822
# XLK     0.3182
# XLP     0.0559
# XLRE    0.0208
# XLU     0.0235
# XLV     0.1014
# XLY     0.1084
# dtype: float64

# %%
# Create a list of the ticker symbols:
sector_etfs = weight_series.index.tolist()
n_sectors = len(sector_etfs)

# %%
# This is the weight vector we'll be working with:
w = weight_series.to_numpy()

# %% [markdown]
# **Implied volatility of SPY**

# %%
display(Latex('σ_\mathrm{SPY}'))
# Out:
# σ_\mathrm{SPY}

# %% [markdown]
# 30-day IV from Market Chameleon to keep things simple: https://marketchameleon.com/Overview/SPY/DailyHistory

# %%
implied_vol_SPY = 0.116

# %% [markdown]
# **Diagonal matrix of the sector implied volatilities**

# %%
display(Latex('V'))
# Out:
# V

# %% [markdown]
# 30-day IVs from Market Chameleon to keep things simple

# %%
implied_vol_series = pd.Series({'XLB': 0.15, 'XLC': 0.127, 'XLE': 0.188, 'XLF': 0.136, 'XLI': 0.127, 'XLK': 0.19, 'XLP': 0.117, 'XLRE': 0.161, 'XLU': 0.158, 'XLV': 0.122, 'XLY': 0.171})
implied_vol_series
# Out:
# XLB     0.150
# XLC     0.127
# XLE     0.188
# XLF     0.136
# XLI     0.127
# XLK     0.190
# XLP     0.117
# XLRE    0.161
# XLU     0.158
# XLV     0.122
# XLY     0.171
# dtype: float64

# %%
V = np.diag(implied_vol_series)

# %% [markdown]
# **Benchmark correlation matrix**

# %%
display(Latex('C_B'))
# Out:
# C_B

# %% [markdown]
# Historical correlation matrix to keep things simple

# %%
# Gather daily returns over the past month:
return_df = yf.download(sector_etfs, start='2025-01-16', end='2025-02-19', rounding=True, progress=False)['Close'].pct_change().dropna()
return_df
# Out:
# Ticker           XLB       XLC       XLE       XLF       XLI       XLK  \
# Date
# 2025-01-17  0.006495  0.008700  0.007722  0.008432  0.005988  0.015662
# 2025-01-21  0.012793  0.009036 -0.005109  0.008362  0.020544  0.008329
# 2025-01-22 -0.008048  0.009973 -0.018186 -0.004738 -0.002347  0.022579
# 2025-01-23  0.005522  0.002620  0.004576  0.005753  0.010125  0.001781
# 2025-01-24 -0.002578  0.009044 -0.009653  0.002959 -0.004235 -0.010421
# 2025-01-27  0.000562  0.005179 -0.010404  0.011013 -0.013398 -0.049018
# 2025-01-28 -0.003257  0.004855 -0.009517 -0.001751 -0.006610  0.026673
# 2025-01-29 -0.001803  0.004437  0.002235 -0.000779 -0.003399 -0.008132
# 2025-01-30  0.009481  0.000982  0.005128  0.009555  0.011176  0.001856
# 2025-01-31 -0.007267  0.004021 -0.027950 -0.005795 -0.007034 -0.005858
# 2025-02-03  0.001014  0.002149  0.006276 -0.004080 -0.009902 -0.013474
# 2025-02-04  0.002925  0.008967  0.020977 -0.002341  0.000292  0.014405
# 2025-02-05 -0.000785 -0.009660  0.002110  0.010559  0.000730  0.013897
# 2025-02-06  0.003480  0.004292 -0.018397  0.008320  0.004522  0.002733
# 2025-02-07 -0.012195 -0.002137 -0.000113 -0.005565 -0.002977 -0.008559
# 2025-02-10  0.005097  0.004477  0.022019 -0.007912  0.008957  0.014604
# 2025-02-11  0.005860  0.001647  0.008065  0.002529  0.000361  0.000466
# 2025-02-12 -0.007170  0.001064 -0.024112 -0.003492 -0.006204 -0.002158
# 2025-02-13  0.017378  0.011500  0.007525  0.006620  0.001016  0.014163
# 2025-02-14 -0.003438  0.006114  0.004013  0.001934 -0.002466  0.003387
# 2025-02-18  0.012688 -0.004653  0.013656  0.007143  0.007852  0.009126
#
# Ticker           XLP      XLRE       XLU       XLV       XLY
# Date
# 2025-01-17  0.005729 -0.000243  0.001397 -0.006731  0.014023
# 2025-01-21  0.004661  0.018257  0.015348  0.016550  0.007329
# 2025-01-22 -0.004897 -0.017452 -0.021611 -0.002246 -0.003768
# 2025-01-23  0.003626  0.008029  0.004724  0.013363  0.006043
# 2025-01-24  0.005161  0.002896  0.010166  0.001596 -0.006093
# 2025-01-27  0.027086  0.009868 -0.023148  0.022452  0.005695
# 2025-01-28 -0.015623 -0.012154 -0.013780 -0.006981  0.001210
# 2025-01-29  0.002412 -0.011580  0.002089 -0.005870 -0.002850
# 2025-01-30  0.009880  0.013180  0.020850  0.011534  0.009786
# 2025-01-31 -0.009407 -0.002168 -0.005872 -0.003190 -0.004417
# 2025-02-03  0.003925 -0.001690  0.005393  0.003881 -0.013223
# 2025-02-04 -0.008450  0.000000 -0.008812 -0.002713  0.011785
# 2025-02-05  0.006233  0.015719  0.010050  0.009589 -0.011346
# 2025-02-06  0.004551  0.002857 -0.001148 -0.008959  0.003971
# 2025-02-07 -0.001510 -0.003561 -0.002043 -0.004690 -0.019558
# 2025-02-10  0.006175  0.001430  0.010878 -0.000888  0.003413
# 2025-02-11  0.009644  0.005472  0.005064 -0.001846 -0.011354
# 2025-02-12 -0.000744 -0.008519 -0.001763 -0.001438 -0.000179
# 2025-02-13  0.010801  0.007876  0.002271  0.003909  0.015017
# 2025-02-14 -0.009948 -0.004026 -0.004155 -0.010861 -0.000440
# 2025-02-18  0.003598  0.003566  0.009355 -0.001934 -0.002775

# %%
hist_corr_matrix = return_df.corr()
hist_corr_matrix
# Out:
# Ticker       XLB       XLC       XLE       XLF       XLI       XLK       XLP  \
# Ticker
# XLB     1.000000  0.153030  0.535379  0.599706  0.653714  0.206573  0.463762
# XLC     0.153030  1.000000 -0.086916 -0.116191  0.014299  0.097612 -0.082660
# XLE     0.535379 -0.086916  1.000000  0.083319  0.385097  0.239254  0.164225
# XLF     0.599706 -0.116191  0.083319  1.000000  0.376821 -0.136931  0.597102
# XLI     0.653714  0.014299  0.385097  0.376821  1.000000  0.468872  0.100547
# XLK     0.206573  0.097612  0.239254 -0.136931  0.468872  1.000000 -0.566091
# XLP     0.463762 -0.082660  0.164225  0.597102  0.100547 -0.566091  1.000000
# XLRE    0.644107 -0.220578  0.283773  0.721625  0.526084 -0.186815  0.618028
# XLU     0.520719 -0.309697  0.410881  0.275404  0.659575  0.159124  0.218253
# XLV     0.357438 -0.090116  0.021961  0.505862  0.204593 -0.428368  0.666901
# XLY     0.604976  0.572484  0.180012  0.404931  0.415211  0.229300  0.164891
#
# Ticker      XLRE       XLU       XLV       XLY
# Ticker
# XLB     0.644107  0.520719  0.357438  0.604976
# XLC    -0.220578 -0.309697 -0.090116  0.572484
# XLE     0.283773  0.410881  0.021961  0.180012
# XLF     0.721625  0.275404  0.505862  0.404931
# XLI     0.526084  0.659575  0.204593  0.415211
# XLK    -0.186815  0.159124 -0.428368  0.229300
# XLP     0.618028  0.218253  0.666901  0.164891
# XLRE    1.000000  0.576828  0.710839  0.244409
# XLU     0.576828  1.000000  0.181602 -0.004798
# XLV     0.710839  0.181602  1.000000  0.194219
# XLY     0.244409 -0.004798  0.194219  1.000000

# %%
C_B = hist_corr_matrix.to_numpy()

# %% [markdown]
# # Solve for the implied covariance matrix:

# %% [markdown]
# We must first solve for the implied correlation matrix

# %% [markdown]
# **Implied correlation matrix**

# %%
display(Latex('C'))
# Out:
# C

# %% [markdown]
# Since there's 11 sectors, we need an 11x11 implied correlation matrix

# %% [markdown]
# This means we're solving for 55 unique correlation values

# %%
display(Latex('\dfrac{n(n-1)}{2}'))
# Out:
# \dfrac{n(n-1)}{2}

# %% [markdown]
# Structure as a constrained minimization problem

# %%
target_variance = implied_vol_SPY**2

# %%
# Function to construct the full correlation matrix from the 55 unique values:
def construct_corr_matrix(unique_values):
    C = np.eye(n_sectors)
    upper_triangle_indices = np.triu_indices(n_sectors, k=1)
    C[upper_triangle_indices] = unique_values
    C[(upper_triangle_indices[1], upper_triangle_indices[0])] = unique_values  # Symmetric
    return C

# %%
# Frobenius norm of the difference between C and C_B:
def objective(unique_values):
    C = construct_corr_matrix(unique_values)
    return np.linalg.norm(C - C_B, 'fro')  # This is what we're minimizing.

# %%
# Portfolio variance equality constraint:
def portfolio_variance_constraint(unique_values):
    C = construct_corr_matrix(unique_values)
    return target_variance - (w.T @ (V @ C @ V) @ w)  # As an equality constraint, this equation must equal zero.

# %%
# Positive semidefinite inequality constraint:
def positive_semidefinite_constraint(unique_values):
    C = construct_corr_matrix(unique_values)
    eigenvalues = np.linalg.eigvalsh(C)
    return eigenvalues  # As an inequality constraint, each eigenvalue must be >= 0.

# %%
# Use the 55 unique values from C_B as the initial guess:
initial_guess = C_B[np.triu_indices(n_sectors, k=1)]

# %%
# Define the constraints:
constraints = [
    {'type': 'eq', 'fun': portfolio_variance_constraint},
    {'type': 'ineq', 'fun': positive_semidefinite_constraint}
]

# %%
# Define the bounds for each unique correlation value:
bounds = [(-1, 1)] * len(initial_guess)

# %%
# Solve the minimization problem:
result = minimize(
    objective,
    initial_guess,
    method='SLSQP',
    constraints=constraints,
    bounds=bounds,
    options={'disp': True, 'maxiter': 1000}
)
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0188529336067362
#             Iterations: 62
#             Function evaluations: 3812
#             Gradient evaluations: 62

# %%
# Construct the full implied correlation matrix from the optimized unique values:
C = construct_corr_matrix(result.x)

# %%
implied_corr_matrix = pd.DataFrame(C, index=sector_etfs, columns=sector_etfs)
implied_corr_matrix
# Out:
#            XLB       XLC       XLE       XLF       XLI       XLK       XLP  \
# XLB   1.000000  0.173214  0.532788  0.615890  0.649469  0.407916  0.499192
# XLC   0.173214  1.000000 -0.017986  0.093977  0.131190  0.550232 -0.054108
# XLE   0.532788 -0.017986  1.000000  0.204930  0.461554  0.406830  0.162037
# XLF   0.615890  0.093977  0.204930  1.000000  0.583171  0.502848  0.621577
# XLI   0.649469  0.131190  0.461554  0.583171  1.000000  0.763729  0.099056
# XLK   0.407916  0.550232  0.406830  0.502848  0.763729  1.000000 -0.161071
# XLP   0.499192 -0.054108  0.162037  0.621577  0.099056 -0.161071  1.000000
# XLRE  0.669723 -0.215969  0.272150  0.711556  0.507982  0.066019  0.672240
# XLU   0.517469 -0.274497  0.435835  0.339861  0.702568  0.268550  0.221576
# XLV   0.382986  0.019720  0.076223  0.677990  0.298052  0.085432  0.719655
# XLY   0.598816  0.726898  0.286188  0.683433  0.599846  0.850009  0.209798
#
#           XLRE       XLU       XLV       XLY
# XLB   0.669723  0.517469  0.382986  0.598816
# XLC  -0.215969 -0.274497  0.019720  0.726898
# XLE   0.272150  0.435835  0.076223  0.286188
# XLF   0.711556  0.339861  0.677990  0.683433
# XLI   0.507982  0.702568  0.298052  0.599846
# XLK   0.066019  0.268550  0.085432  0.850009
# XLP   0.672240  0.221576  0.719655  0.209798
# XLRE  1.000000  0.573872  0.736510  0.254329
# XLU   0.573872  1.000000  0.213689  0.070015
# XLV   0.736510  0.213689  1.000000  0.351272
# XLY   0.254329  0.070015  0.351272  1.000000

# %%
# Check if it equals the benchmark correlation matrix:
np.allclose(C, C_B)
# Out:
# False

# %%
# Make sure its smallest eigenvalue is >= 0:
np.min(np.linalg.eigvalsh(C))
# Out:
# -9.682217289685396e-07

# %% [markdown]
# **Implied covariance matrix**

# %%
# Convert to the implied covariance matrix:
Σ = V @ C @ V

# %%
implied_cov_matrix = pd.DataFrame(Σ, index=sector_etfs, columns=sector_etfs)
implied_cov_matrix
# Out:
#            XLB       XLC       XLE       XLF       XLI       XLK       XLP  \
# XLB   0.022500  0.003300  0.015025  0.012564  0.012372  0.011626  0.008761
# XLC   0.003300  0.016129 -0.000429  0.001623  0.002116  0.013277 -0.000804
# XLE   0.015025 -0.000429  0.035344  0.005240  0.011020  0.014532  0.003564
# XLF   0.012564  0.001623  0.005240  0.018496  0.010073  0.012994  0.009891
# XLI   0.012372  0.002116  0.011020  0.010073  0.016129  0.018429  0.001472
# XLK   0.011626  0.013277  0.014532  0.012994  0.018429  0.036100 -0.003581
# XLP   0.008761 -0.000804  0.003564  0.009891  0.001472 -0.003581  0.013689
# XLRE  0.016174 -0.004416  0.008237  0.015580  0.010387  0.002020  0.012663
# XLU   0.012264 -0.005508  0.012946  0.007303  0.014098  0.008062  0.004096
# XLV   0.007009  0.000306  0.001748  0.011249  0.004618  0.001980  0.010272
# XLY   0.015360  0.015786  0.009200  0.015894  0.013027  0.027617  0.004197
#
#           XLRE       XLU       XLV       XLY
# XLB   0.016174  0.012264  0.007009  0.015360
# XLC  -0.004416 -0.005508  0.000306  0.015786
# XLE   0.008237  0.012946  0.001748  0.009200
# XLF   0.015580  0.007303  0.011249  0.015894
# XLI   0.010387  0.014098  0.004618  0.013027
# XLK   0.002020  0.008062  0.001980  0.027617
# XLP   0.012663  0.004096  0.010272  0.004197
# XLRE  0.025921  0.014598  0.014467  0.007002
# XLU   0.014598  0.024964  0.004119  0.001892
# XLV   0.014467  0.004119  0.014884  0.007328
# XLY   0.007002  0.001892  0.007328  0.029241

# %%
# Make sure the portfolio variance constraint is satisfied:
target_variance - (w.T @ Σ @ w)
# Out:
# -3.9343528435153985e-15

# %% [markdown]
# # Final code:

# %%
# Gather known data:
weight_series = pd.Series({'XLB': 0.0198, 'XLC': 0.0966, 'XLE': 0.0321, 'XLF': 0.1411, 'XLI': 0.0822, 'XLK': 0.3182, 'XLP': 0.0559, 'XLRE': 0.0208, 'XLU': 0.0235, 'XLV': 0.1014, 'XLY': 0.1084})
w = weight_series.to_numpy()

sector_etfs = weight_series.index.tolist()
n_sectors = len(sector_etfs)

implied_vol_SPY = 0.116

implied_vol_series = pd.Series({'XLB': 0.15, 'XLC': 0.127, 'XLE': 0.188, 'XLF': 0.136, 'XLI': 0.127, 'XLK': 0.19, 'XLP': 0.117, 'XLRE': 0.161, 'XLU': 0.158, 'XLV': 0.122, 'XLY': 0.171})
V = np.diag(implied_vol_series)

return_df = yf.download(sector_etfs, start='2025-01-16', end='2025-02-19', rounding=True, progress=False)['Close'].pct_change().dropna()
hist_corr_matrix = return_df.corr()
C_B = hist_corr_matrix.to_numpy()

# Solve for the implied covariance matrix:
target_variance = implied_vol_SPY**2

def construct_corr_matrix(unique_values):
    C = np.eye(n_sectors)
    upper_triangle_indices = np.triu_indices(n_sectors, k=1)
    C[upper_triangle_indices] = unique_values
    C[(upper_triangle_indices[1], upper_triangle_indices[0])] = unique_values
    return C

def objective(unique_values):
    C = construct_corr_matrix(unique_values)
    return np.linalg.norm(C - C_B, 'fro')

def portfolio_variance_constraint(unique_values):
    C = construct_corr_matrix(unique_values)
    return target_variance - (w.T @ (V @ C @ V) @ w)

def positive_semidefinite_constraint(unique_values):
    C = construct_corr_matrix(unique_values)
    eigenvalues = np.linalg.eigvalsh(C)
    return eigenvalues

initial_guess = C_B[np.triu_indices(n_sectors, k=1)]

constraints = [
    {'type': 'eq', 'fun': portfolio_variance_constraint},
    {'type': 'ineq', 'fun': positive_semidefinite_constraint}
]

bounds = [(-1, 1)] * len(initial_guess)

result = minimize(
    objective,
    initial_guess,
    method='SLSQP',
    constraints=constraints,
    bounds=bounds,
    options={'disp': True, 'maxiter': 1000}
)

C = construct_corr_matrix(result.x)
implied_corr_matrix = pd.DataFrame(C, index=sector_etfs, columns=sector_etfs)

Σ = V @ C @ V
implied_cov_matrix = pd.DataFrame(Σ, index=sector_etfs, columns=sector_etfs)

implied_cov_matrix
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2.0188529336067362
#             Iterations: 62
#             Function evaluations: 3812
#             Gradient evaluations: 62
#            XLB       XLC       XLE       XLF       XLI       XLK       XLP  \
# XLB   0.022500  0.003300  0.015025  0.012564  0.012372  0.011626  0.008761
# XLC   0.003300  0.016129 -0.000429  0.001623  0.002116  0.013277 -0.000804
# XLE   0.015025 -0.000429  0.035344  0.005240  0.011020  0.014532  0.003564
# XLF   0.012564  0.001623  0.005240  0.018496  0.010073  0.012994  0.009891
# XLI   0.012372  0.002116  0.011020  0.010073  0.016129  0.018429  0.001472
# XLK   0.011626  0.013277  0.014532  0.012994  0.018429  0.036100 -0.003581
# XLP   0.008761 -0.000804  0.003564  0.009891  0.001472 -0.003581  0.013689
# XLRE  0.016174 -0.004416  0.008237  0.015580  0.010387  0.002020  0.012663
# XLU   0.012264 -0.005508  0.012946  0.007303  0.014098  0.008062  0.004096
# XLV   0.007009  0.000306  0.001748  0.011249  0.004618  0.001980  0.010272
# XLY   0.015360  0.015786  0.009200  0.015894  0.013027  0.027617  0.004197
#
#           XLRE       XLU       XLV       XLY
# XLB   0.016174  0.012264  0.007009  0.015360
# XLC  -0.004416 -0.005508  0.000306  0.015786
# XLE   0.008237  0.012946  0.001748  0.009200
# XLF   0.015580  0.007303  0.011249  0.015894
# XLI   0.010387  0.014098  0.004618  0.013027
# XLK   0.002020  0.008062  0.001980  0.027617
# XLP   0.012663  0.004096  0.010272  0.004197
# XLRE  0.025921  0.014598  0.014467  0.007002
# XLU   0.014598  0.024964  0.004119  0.001892
# XLV   0.014467  0.004119  0.014884  0.007328
# XLY   0.007002  0.001892  0.007328  0.029241
